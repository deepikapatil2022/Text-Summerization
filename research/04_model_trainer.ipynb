# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class ModelTrainerConfig:
    root_dir: Path
    data_path: Path
    model_ckpt: Path
    num_train_epochs: int
    warmup_steps: int
    per_device_train_batch_size: int
    weight_decay: float
    logging_steps: int
    evaluation_strategy: str
    eval_steps: int
    save_steps: float
    gradient_accumulation_steps: int

# %%
from Textsummerizer.constant import *
from Textsummerizer.utils.common import read_yaml,create_directories

class ConfigurationManager:
    def __init__(
            self,
            config_filepath = CONFIG_FILE_PATH,
            params_filepath = PARAMS_FILE_PATH):
            self.config = read_yaml(config_filepath)
            self.params = read_yaml(params_filepath)

            create_directories([self.config.artifacts_root])

    def get_model_trainer_config(self) -> ModelTrainerConfig:
        config = self.config.model_trainer
        params = self.params.TrainingArguments

        create_directories([config.root_dir])

        model_trainer_config = ModelTrainerConfig(
            root_dir=config.root_dir,
            data_path=config.data_path,
            model_ckpt = config.model_ckpt,
            num_train_epochs = params.num_train_epochs,
            warmup_steps = params.warmup_steps,
            per_device_train_batch_size = params.per_device_train_batch_size,
            weight_decay = params.weight_decay,
            logging_steps = params.logging_steps,
            evaluation_strategy = params.evaluation_strategy,
            eval_steps = params.evaluation_strategy,
            save_steps = params.save_steps,
            gradient_accumulation_steps = params.gradient_accumulation_steps
        )

        return model_trainer_config

# %%
from transformers import TrainingArguments, Trainer
from transformers import DataCollatorForSeq2Seq
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from datasets import load_dataset, load_from_disk
import torch

# %%
class ModelTrainer:
    def __init__(self, config: ModelTrainerConfig):
        self.config = config

    def train(self):
        device = "cuda" if torch.cuda.is_available() else "cpu"
        tokenizer = AutoTokenizer.from_pretrained(self.config.model_ckpt)
        model_pegasus = AutoModelForSeq2SeqLM.from_pretrained(self.config.model_ckpt).to(device)
        seq2seq_data_collator = DataCollatorForSeq2Seq(tokenizer, model=model_pegasus)
        
        #loading data 
        dataset_samsum_pt = load_from_disk(self.config.data_path)

        # trainer_args = TrainingArguments(
        #     output_dir=self.config.root_dir, num_train_epochs=self.config.num_train_epochs, warmup_steps=self.config.warmup_steps,
        #     per_device_train_batch_size=self.config.per_device_train_batch_size, per_device_eval_batch_size=self.config.per_device_train_batch_size,
        #     weight_decay=self.config.weight_decay, logging_steps=self.config.logging_steps,
        #     evaluation_strategy=self.config.evaluation_strategy, eval_steps=self.config.eval_steps, save_steps=1e6,
        #     gradient_accumulation_steps=self.config.gradient_accumulation_steps
        # ) 


        trainer_args = TrainingArguments(
            output_dir=self.config.root_dir, num_train_epochs=1, warmup_steps=500,
            per_device_train_batch_size=1, per_device_eval_batch_size=1,
            weight_decay=0.01, logging_steps=10,
            evaluation_strategy='steps', eval_steps=500, save_steps=1e6,
            gradient_accumulation_steps=16
        ) 

        trainer = Trainer(model=model_pegasus, args=trainer_args,
                  tokenizer=tokenizer, data_collator=seq2seq_data_collator,
                  train_dataset=dataset_samsum_pt["train"], 
                  eval_dataset=dataset_samsum_pt["validation"])
        
        trainer.train()

        ## Save model
        model_pegasus.save_pretrained(os.path.join(self.config.root_dir,"pegasus-samsum-model"))
        ## Save tokenizer
        tokenizer.save_pretrained(os.path.join(self.config.root_dir,"tokenizer"))

# %%
try:
    config = ConfigurationManager()
    model_trainer_config = config.get_model_trainer_config()
    model_trainer_config = ModelTrainer(config=model_trainer_config)
    model_trainer_config.train()
except Exception as e:8
    raise e
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 7
#       5     model_trainer_config.train()
#       6 except Exception as e:
# ----> 7     raise e
#
# Cell In[10], line 2
#       1 try:
# ----> 2     config = ConfigurationManager()
#       3     model_trainer_config = config.get_model_trainer_config()
#       4     model_trainer_config = ModelTrainer(config=model_trainer_config)
#
# Cell In[2], line 9, in ConfigurationManager.__init__(self, config_filepath, params_filepath)
#       5 def __init__(
#       6         self,
#       7         config_filepath = CONFIG_FILE_PATH,
#       8         params_filepath = PARAMS_FILE_PATH):
# ----> 9         self.config = read_yaml(config_filepath)
#      10         self.params = read_yaml(params_filepath)
#      12         create_directories([self.config.artifacts_root])
#
# File c:\Users\DIPIKA\anaconda33\envs\texts\lib\site-packages\ensure\main.py:849, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
#     845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
# --> 849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#     851     msg = (
#     852         "Return value of {f} of type {valt} "
#     853         "does not match annotation type {t}"
#     854     )
#
# File d:\text-summerization\src\Textsummerizer\utils\common.py:33, in read_yaml(path_to_yaml)
#      31     raise ValueError("yaml file is empty")
#      32 except Exception as e:
# ---> 33     raise e
#
# File d:\text-summerization\src\Textsummerizer\utils\common.py:26, in read_yaml(path_to_yaml)
#      12 """reads yaml file and returns
#      13
#      14 Args:
#    (...)
#      22     ConfigBox: ConfigBox type
#      23 """
#      25 try:
# ---> 26     with open (path_to_yaml) as yaml_file:
#      27         content=yaml.safe_load(yaml_file)
#      28         logger.info(f"yaml file : {path_to_yaml} loaded successfully")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config\\config.yaml'

# %%
# !pip install --upgrade accelerate
# !pip uninstall -y transformers accelerate
# !pip install transformers accelerate
# Out:
# Collecting accelerate
#   Downloading accelerate-0.30.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from accelerate) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: pyyaml in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from accelerate) (2.3.0)
# Requirement already satisfied: huggingface-hub in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from accelerate) (0.22.2)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from torch>=1.10.0->accelerate) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from torch>=1.10.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from torch>=1.10.0->accelerate) (2024.3.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from torch>=1.10.0->accelerate) (2021.4.0)
# Requirement already satisfied: requests in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.10.0->accelerate) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.10.0->accelerate) (2021.12.0)
# Requirement already satisfied: colorama in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from tqdm>=4.42.1->huggingface-hub->accelerate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from requests->huggingface-hub->accelerate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading accelerate-0.30.0-py3-none-any.whl (302 kB)
#    ---------------------------------------- 0.0/302.4 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/302.4 kB 660.6 kB/s eta 0:00:01
#    ----------- --------------------------- 92.2/302.4 kB 751.6 kB/s eta 0:00:01
#    ----------- --------------------------- 92.2/302.4 kB 751.6 kB/s eta 0:00:01
#    -------------- ----------------------- 112.6/302.4 kB 504.4 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/302.4 kB 532.5 kB/s eta 0:00:01
#    --------------------- ---------------- 174.1/302.4 kB 583.1 kB/s eta 0:00:01
#    ---------------------------- --------- 225.3/302.4 kB 655.6 kB/s eta 0:00:01
#    ----------------------------- -------- 235.5/302.4 kB 577.6 kB/s eta 0:00:01
#    ----------------------------- -------- 235.5/302.4 kB 577.6 kB/s eta 0:00:01
#    ----------------------------- -------- 235.5/302.4 kB 577.6 kB/s eta 0:00:01
#    ----------------------------- -------- 235.5/302.4 kB 577.6 kB/s eta 0:00:01
#    ----------------------------- -------- 235.5/302.4 kB 577.6 kB/s eta 0:00:01
#    ---------------------------------- --- 276.5/302.4 kB 426.0 kB/s eta 0:00:01
#    ------------------------------------ - 286.7/302.4 kB 412.0 kB/s eta 0:00:01
#    -------------------------------------- 302.4/302.4 kB 415.6 kB/s eta 0:00:00
# Installing collected packages: accelerate
# Successfully installed accelerate-0.30.0
# Found existing installation: transformers 4.40.1
# Uninstalling transformers-4.40.1:
#   Successfully uninstalled transformers-4.40.1
# Found existing installation: accelerate 0.30.0
# Uninstalling accelerate-0.30.0:
#   Successfully uninstalled accelerate-0.30.0
# Collecting transformers
#   Downloading transformers-4.40.2-py3-none-any.whl.metadata (137 kB)
#      ---------------------------------------- 0.0/138.0 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/138.0 kB ? eta -:--:--
#      ---------- -------------------------- 41.0/138.0 kB 393.8 kB/s eta 0:00:01
#      ---------------- -------------------- 61.4/138.0 kB 469.7 kB/s eta 0:00:01
#      ------------------------------------ 138.0/138.0 kB 742.7 kB/s eta 0:00:00
# Collecting accelerate
#   Using cached accelerate-0.30.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from transformers) (2024.4.28)
# Requirement already satisfied: requests in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from transformers) (4.66.2)
# Requirement already satisfied: psutil in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: torch>=1.10.0 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from accelerate) (2.3.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: sympy in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from torch>=1.10.0->accelerate) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.10.0->accelerate) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.10.0->accelerate) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\dipika\anaconda33\envs\texts\lib\site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading transformers-4.40.2-py3-none-any.whl (9.0 MB)
#    ---------------------------------------- 0.0/9.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.0 MB 3.2 MB/s eta 0:00:03
#     --------------------------------------- 0.1/9.0 MB 1.3 MB/s eta 0:00:07
#     --------------------------------------- 0.2/9.0 MB 1.3 MB/s eta 0:00:07
#    - -------------------------------------- 0.2/9.0 MB 1.4 MB/s eta 0:00:07
#    - -------------------------------------- 0.3/9.0 MB 1.1 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/9.0 MB 1.2 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/9.0 MB 1.3 MB/s eta 0:00:07
#    -- ------------------------------------- 0.5/9.0 MB 1.2 MB/s eta 0:00:07
#    -- ------------------------------------- 0.5/9.0 MB 1.2 MB/s eta 0:00:08
#    -- ------------------------------------- 0.5/9.0 MB 1.2 MB/s eta 0:00:08
#    -- ------------------------------------- 0.6/9.0 MB 1.1 MB/s eta 0:00:08
#    -- ------------------------------------- 0.6/9.0 MB 1.2 MB/s eta 0:00:08
#    --- ------------------------------------ 0.7/9.0 MB 1.1 MB/s eta 0:00:08
#    --- ------------------------------------ 0.7/9.0 MB 1.1 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/9.0 MB 1.1 MB/s eta 0:00:08
#    --- ------------------------------------ 0.9/9.0 MB 1.1 MB/s eta 0:00:08
#    --- ------------------------------------ 0.9/9.0 MB 1.1 MB/s eta 0:00:08
#    ---- ----------------------------------- 0.9/9.0 MB 1.1 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.0/9.0 MB 1.1 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.0/9.0 MB 1.1 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.1/9.0 MB 1.1 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.1/9.0 MB 1.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.2/9.0 MB 1.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.2/9.0 MB 1.0 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.3/9.0 MB 1.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.3/9.0 MB 1.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.3/9.0 MB 1.1 MB/s eta 0:00:08
#    ------ --------------------------------- 1.4/9.0 MB 1.1 MB/s eta 0:00:08
#    ------ --------------------------------- 1.5/9.0 MB 1.1 MB/s eta 0:00:08
#    ------ --------------------------------- 1.5/9.0 MB 1.1 MB/s eta 0:00:08
